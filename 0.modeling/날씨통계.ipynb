# %%
from google.colab import auth
auth.authenticate_user()
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# %pwd
# Out:
# '/content'

# %%
% cd /content/drive/My Drive/수퍼판다
# Out:
# /content/drive/My Drive/수퍼판다

# %%
import pandas as pd

nolist = ['공릉1동', '공릉2동', '상계1동', '상계2동',
             '상계5', '상계10동', '상계34동', '상계67동',
             '월계1동', '월계3동', '중계23동', '중계본동',
             '하계1동']
           
nowon = {}
for dong in nolist:
    file = "/content/drive/My Drive/수퍼판다/★새출발★/일별미세먼지대표값/노원구/{}.csv".format(dong)
    nowon[dong] = pd.read_csv(file)
    #nowon[dong].set_index(pd.to_datetime(nowon[dong].temp), inplace=True)
    #nowon[dong].drop('Unnamed: 0', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-bbdcd1e2d03a> in <module>()
#       9 for dong in nolist:
#      10     file = "/content/drive/My Drive/수퍼판다/★새출발★/일별미세먼지대표값/노원구/{}.csv".format(dong)
# ---> 11     nowon[dong] = pd.read_csv(file)
#      12     #nowon[dong].set_index(pd.to_datetime(nowon[dong].temp), inplace=True)
#      13     #nowon[dong].drop('Unnamed: 0', axis=1, inplace=True)
#
# ...

# %%
jong_list = ['종로_가회동', '종로_교남동', '종로_부암동', '종로_사직동',
             '종로_숭인2동', '종로_이화동', '종로_종로56가동', '종로_종로1234가동',
             '종로_창신1동', '종로_창신3동', '종로_청운효자동', '종로_평창동',
             '종로_혜화동']

jongro = {}
for dong in jong_list:
    filepath = 'C:\Python\JupyterNotebook\[공모전]빅콘\DATASET(미세먼지)\전처리\종로구\{}.csv'.format(dong)
    jongro[dong] = pd.read_csv(filepath)
    #jongro[dong].set_index(pd.to_datetime(jongro[dong].temp), inplace=True)
    #jongro[dong].drop('Unnamed: 0', axis=1, inplace=True)
