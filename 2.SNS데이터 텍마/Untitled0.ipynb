# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/My Drive/수퍼판다
# Out:
# /content/drive/My Drive/수퍼판다

# %%
cafe = pd.read_csv('./2.SNS데이터 텍마/cafe.csv')
blog = pd.read_csv('./2.SNS데이터 텍마/blog.csv')

# %%
pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4MB 1.0MB/s
# ...
#      |████████████████████████████████| 2.7MB 39.8MB/s
# ...

# %%
import konlpy.tag
import re

# %%
from datetime import datetime

blog['DATE'] = blog.DATE.apply(lambda x: str(x)[:-9])
blog['DATE'] = blog.DATE.apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
len(blog)
# Out:
# 302548

# %%
blog.head()
# Out:
#         DATE  ...                                            CONTENT
# 0 2019-02-17  ...  다이어트일기 20190216 다이어트일기 DAY327 뷰스타 디이니  2019 2 ...
# 1 2019-02-17  ...  그린슈트 투자스토리 한전KPS 문재인 정부 탈원전 정책은 매수기회일까 배당 과대낙폭...
# 2 2019-02-17  ...  매일매일 아직은 살만한 세상 은캐랠리  2019 2 17 2354 URL 복사 이웃...
# 3 2019-02-17  ...  □ 시사원정대 시사원정대 읽고 신문일기 쓰고 최신뉴스에 관심을 가져요 널그리다  2...
# 4 2019-02-17  ...    동그랗게 생긴 잎에 점이 하나  콕 하고 찍혀 있는 모습이 귀여운  필레아페페로...
#
# [5 rows x 5 columns]

# %%
blog.pivot_table(index='DATE',
                aggfunc='count',
                values='DOCID')

# 날별로 900개 이상 존재

# %%
미먼용어 =['미세먼지','약도라지꿀청', '핸드워시','손세정제','미니공기청정기','공기청정기','공기','모공','효능','마스크','실내공기질관리법',
       '코세척기','날','날씨','어린이','노인','청소기','무선청소기','진공청소기','목에 좋은','사진','예방','환기','집안']

# %%
re.sub(r'[^\d\s\w]',' ', blog.iloc[1]['TITLE'])
# Out:
# '한전KPS 문재인 정부 탈원전 정책은 매수기회일까 배당'

# %%
twitter= konlpy.tag.Twitter()
# Out:
# /usr/local/lib/python3.6/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# /usr/local/lib/python3.6/dist-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
type(blog.iloc[0]['TITLE'])
# Out:
# str

# %%
Noun_words = []
num = range(len(blog))

for i in num:
  morphs =  twitter.pos(blog['TITLE'].iloc[i])
  print(morphs)
# Out:
# [('20190216', 'Number'), ('다이어트', 'Noun'), ('일기', 'Noun'), ('DAY', 'Alpha'), ('327', 'Number')]
# [('한전', 'Noun'), ('KPS', 'Alpha'), ('문재인', 'Noun'), ('정부', 'Noun'), ('탈', 'Noun'), ('원전', 'Noun'), ('정책', 'Noun'), ('은', 'Josa'), ('매', 'Modifier'), ('수', 'Modifier'), ('기회', 'Noun'), ('일까', 'Verb'), ('배당', 'Noun')]
# [('아직', 'Adverb'), ('은', 'Noun'), ('살', 'Noun'), ('만', 'Suffix'), ('한', 'Josa'), ('세상', 'Noun')]
# [('시', 'Modifier'), ('사', 'Modifier'), ('원정', 'Noun'), ('대', 'Suffix'), ('읽고', 'Verb'), ('신문', 'Noun'), ('일기', 'Noun'), ('쓰고', 'Verb'), ('최신', 'Noun'), ('뉴스', 'Noun'), ('에', 'Josa'), ('관심', 'Noun'), ('을', 'Josa'), ('가져요', 'Verb')]
# [('수경재배', 'Noun'), ('가능한', 'Adjective'), ('필레', 'Noun'), ('아', 'Josa'), ('페페', 'Noun'), ('로미오', 'Noun'), ('이', 'Determiner'), ('데스', 'Noun')]
# [('일상', 'Noun'), ('190211', 'Number'), ('190217', 'Number')]
# ...

# %%
word = pd.clipboard()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-304386f99d6f> in <module>()
# ----> 1 word = pd.clipboard()
#
# AttributeError: module 'pandas' has no attribute 'clipboard'

# %%
Noun_words = []
for i in range(len(twitter_morphs)):
    for word, pos in twitter_morphs[i]:
        if pos == 'Noun':
            Noun_words.append(word)

# %%
pd.DataFrame(filtered.values())

# %%
stopword = ['URL',' 복사','기타','기능','번역보기','본문','이웃추가','전체지도지도닫기']

# %%
filtered
# Out:
# {0: '다이어트일기 20190216 다이어트일기 DAY327 뷰스타 디이니  2019 2 17 2359 URL 복사 이웃추가 본문 기타 기능 번역보기 20190216 다이어트일기 오늘은 날씨가 좋아서 기분이 좋아  날은 춥지만 미세먼지 지수가 좋아서 환기를 시켰더니 집안 공기가 맑고 좋아 어제 오늘 엄마랑 집밥 먹고 했더니 기분도 좋구 조리는 내가 다 했지만 말야   아침에 아니 오후에 느즈막하게 일어나서 딸기 먹기 이제 딸기도 다 먹어서 없어 생각해보니 오늘은 과일을 안먹었구나 딸기가 커서 네 알만 먹어도 배가 빵빵해 그리고 오후에 간식 먹으려고 두유 하나 뜯었어 원래는 딸기가 간식인데 점심 대용으로 딸기를 먹었으니 두유가 간식이야 약콩두유 개인적으로 참 좋아해 내 다이어트일기에도 자주 등장할만큼 근데 요 아이 가격이 너무 사악하다구  무첨가라 단맛이 없어서 싫어하는 사람은 안마시더라 내 입맛에는 딱 맞아 그리고 엄마찬스로 장보기 엄마꺼랑 내꺼랑 해서 장보는데 태반이 내꺼같긴해 단호박 돼지고기 닭가슴살 참치 요거트 깻잎 쌈배추 다 내꺼야 김도 엄마가 하나 사놓으라해서 샀어 엄마 미안      엄마찬스가 세상에서 제일 조아   생각해보면 엄마만큼 다 해주는 사람도 없지 그리고 장 본 걸로 엄마랑 우리집에서 집밥 먹기 집에 있는 반찬이랑 대패불고기 간단히 뚝딱해서 엄마랑 냠냠 우리 엄마가 다 컸다고 엄마 밥도 해준다고 생각해보면 엄마랑 밥을 같이 먹은 날이 많이 없어 우리 엄마 항상 바쁘셨거든 동생도 나도 어렸을 때부터 차려 먹는게 익숙해 아무튼 엄마가 사준 쌈배추에 대패불고기 싸서 엄마가 해준 나물반찬에 밥 먹으니까 괜찮더라구 대패불고기는 그냥 양파 버섯이랑 양념 넣고 휘리리 볶았어 간만에 식탁색깔이 다양한 것 같지 풀때기를 많이 먹으니까 포만감도 크더라구 밤에 간식으로 먹은 아몬드 고소해서 맛있어 다이어트할 때 필수로 챙겨먹어야하는 간식이야 아몬드 먹고 요거트도 먹기 요거트에는 각종 베리류를 넣어서 먹었어 라즈베리 블루베리 블랙베리 등등 내가 좋아하는 
# ...

# %%
twitter= konlpy.tag.Twitter()

twitter_morphs = twitter.pos(blog.iloc[0]['filtered'])
print(twitter_morphs)
