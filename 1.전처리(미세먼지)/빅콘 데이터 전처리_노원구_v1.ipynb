# %% [markdown]
# # 2018.4월~2019.3월까지의 데이터
#
# ## tm: 데이터 측정날짜시간(YYYYMMDDhhmm)
# ## serial: 측정기 고유번호
# ## flag: 실외측정기 구분
# ## pm10 : 미세먼지 PM-10 데이터
# ## temp : 온도 데이터
# ## humi: 습도 데이터
# ## pm25: 미세먼지 PM-2.5 데이터

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# # 데이터 적재(1~22)
# # 불필요 컬럼 제거 / 행정동코드변경 등 (노원구 전체 관측소 22개)
#
# # 1. V10O1610102

# %%
# 필요없는 column 지우고, 결측값 0으로 채우기
V10O1610102 = pd.read_csv('V10O1610102.csv')
V10O1610102.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610102 = V10O1610102.fillna(0)
V10O1610102['serial'] = '하계1동'
V10O1610102 = V10O1610102.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610102['tm'] = V10O1610102.tm.apply(lambda x: str(x))
V10O1610102['tm'] = V10O1610102.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610102 = V10O1610102.set_index(['tm', 'serial'])
one = V10O1610102.unstack()
one = one.swaplevel(0,1,axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-565cc7b5d84f> in <module>()
# ----> 1 V10O1610102 = pd.read_csv('V10O1610102.csv')
#       2 V10O1610102.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
#       3 V10O1610102 = V10O1610102.fillna(0)
#       4 V10O1610102['serial'] = '하계1동'
#       5 V10O1610102 = V10O1610102.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
#
# ...

# %% [markdown]
# # 2. V10O1610200

# %%
V10O1610200 = pd.read_csv('V10O1610200.csv')
V10O1610200.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610200 = V10O1610200.fillna(0)
V10O1610200['serial'] = '상계3.4동'
V10O1610200 = V10O1610200.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610200['tm'] = V10O1610200.tm.apply(lambda x: str(x))
V10O1610200['tm'] = V10O1610200.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610200 = V10O1610200.set_index(['tm', 'serial'])
two = V10O1610200.unstack()
two = two.swaplevel(0,1,axis=1)

# %% [markdown]
# # 3.V10O1610293

# %%
V10O1610293 = pd.read_csv('V10O1610293.csv')
V10O1610293.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610293 = V10O1610293.fillna(0)
V10O1610293['serial'] = '상계3.4동'
V10O1610293 = V10O1610293.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610293['tm'] = V10O1610293.tm.apply(lambda x: str(x))
V10O1610293['tm'] = V10O1610293.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610293 = V10O1610293.set_index(['tm', 'serial'])
three = V10O1610293.unstack()
three = three.swaplevel(0,1,axis=1)

# %% [markdown]
# # 4. V10O1610297

# %%
V10O1610297= pd.read_csv('V10O1610297.csv')
V10O1610297.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610297 = V10O1610297.fillna(0)
V10O1610297['serial'] = '상계5동'
V10O1610297 = V10O1610297.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610297['tm'] = V10O1610297.tm.apply(lambda x: str(x))
V10O1610297['tm'] = V10O1610297.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610297 = V10O1610297.set_index(['tm', 'serial'])
four = V10O1610297.unstack()
four = four.swaplevel(0,1,axis=1)

# %% [markdown]
# # 5. V10O1610312

# %%
V10O1610312= pd.read_csv('V10O1610312.csv')
V10O1610312.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610312 = V10O1610312.fillna(0)
V10O1610312['serial'] = '상계3.4동'
V10O1610312 = V10O1610312.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610312['tm'] = V10O1610312.tm.apply(lambda x: str(x))
V10O1610312['tm'] = V10O1610312.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610312 = V10O1610312.set_index(['tm', 'serial'])
five = V10O1610312.unstack()
five = five.swaplevel(0,1,axis=1)

# %% [markdown]
# # 6. V10O1610351

# %%
V10O1610351= pd.read_csv('V10O1610351.csv')
V10O1610351.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610351 = V10O1610351.fillna(0)
V10O1610351['serial'] = '상계3.4동'
V10O1610351 = V10O1610351.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610351['tm'] = V10O1610351.tm.apply(lambda x: str(x))
V10O1610351['tm'] = V10O1610351.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610351 = V10O1610351.set_index(['tm', 'serial'])
six = V10O1610351.unstack()
six = six.swaplevel(0,1,axis=1)

# %% [markdown]
# # 7. V10O1610356

# %%
V10O1610356= pd.read_csv('V10O1610356.csv')
V10O1610356.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610356 = V10O1610356.fillna(0)
V10O1610356['serial'] = '상계3.4동'
V10O1610356 = V10O1610356.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610356['tm'] = V10O1610356.tm.apply(lambda x: str(x))
V10O1610356['tm'] = V10O1610356.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610356 = V10O1610356.set_index(['tm', 'serial'])
seven = V10O1610356.unstack()
seven = seven.swaplevel(0,1,axis=1)

# %% [markdown]
# # 8. V10O1610376

# %%
V10O1610376= pd.read_csv('V10O1610376.csv')
V10O1610376.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610376 = V10O1610376.fillna(0)
V10O1610376['serial'] = '상계3.4동'
V10O1610376 = V10O1610376.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610376['tm'] = V10O1610376.tm.apply(lambda x: str(x))
V10O1610376['tm'] = V10O1610376.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610376 = V10O1610376.set_index(['tm', 'serial'])
eight = V10O1610376.unstack()
eight = eight.swaplevel(0,1,axis=1)

# %% [markdown]
# # 9. V10O1610610

# %%
V10O1610610= pd.read_csv('V10O1610610.csv')
V10O1610610.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610610 = V10O1610610.fillna(0)
V10O1610610['serial'] = '하계1동'
V10O1610610 = V10O1610610.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610610['tm'] = V10O1610610.tm.apply(lambda x: str(x))
V10O1610610['tm'] = V10O1610610.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610610 = V10O1610610.set_index(['tm', 'serial'])
nine = V10O1610610.unstack()
nine = nine.swaplevel(0,1,axis=1)

# %% [markdown]
# # 10.V10O1610616

# %%
V10O1610616= pd.read_csv('V10O1610616.csv')
V10O1610616.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610616 = V10O1610616.fillna(0)
V10O1610616['serial'] = '상계2동'
V10O1610616 = V10O1610616.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610616['tm'] = V10O1610616.tm.apply(lambda x: str(x))
V10O1610616['tm'] = V10O1610616.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610616 = V10O1610616.set_index(['tm', 'serial'])
ten = V10O1610616.unstack()
ten = ten.swaplevel(0,1,axis=1)

# %% [markdown]
# # 11. V10O1610629

# %%
V10O1610629= pd.read_csv('V10O1610629.csv')
V10O1610629.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610629 = V10O1610629.fillna(0)
V10O1610629['serial'] = '공릉2동'
V10O1610629 = V10O1610629.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610629['tm'] = V10O1610629.tm.apply(lambda x: str(x))
V10O1610629['tm'] = V10O1610629.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610629 = V10O1610629.set_index(['tm', 'serial'])
eleven = V10O1610629.unstack()
eleven = eleven.swaplevel(0,1,axis=1)

# %% [markdown]
# # 12. V10O1610630

# %%
V10O1610630= pd.read_csv('V10O1610630.csv')
V10O1610630.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610630 = V10O1610630.fillna(0)
V10O1610630['serial'] = '공릉2동'
V10O1610630 = V10O1610630.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610630['tm'] = V10O1610630.tm.apply(lambda x: str(x))
V10O1610630['tm'] = V10O1610630.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610630 = V10O1610630.set_index(['tm', 'serial'])
twelve = V10O1610630.unstack()
twelve = twelve.swaplevel(0,1,axis=1)

# %% [markdown]
# # 13. V10O1610642

# %%
V10O1610642= pd.read_csv('V10O1610642.csv')
V10O1610642.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610642 = V10O1610642.fillna(0)
V10O1610642['serial'] = '공릉2동'
V10O1610642 = V10O1610642.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610642['tm'] = V10O1610642.tm.apply(lambda x: str(x))
V10O1610642['tm'] = V10O1610642.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610642 = V10O1610642.set_index(['tm', 'serial'])
thirteen = V10O1610642.unstack()
thirteen = thirteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 14. V10O1610643

# %%
V10O1610643= pd.read_csv('V10O1610643.csv')
V10O1610643.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610643 = V10O1610643.fillna(0)
V10O1610643['serial'] = '월계1동'
V10O1610643 = V10O1610643.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610643['tm'] = V10O1610643.tm.apply(lambda x: str(x))
V10O1610643['tm'] = V10O1610643.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610643 = V10O1610643.set_index(['tm', 'serial'])
fourteen = V10O1610643.unstack()
fourteen = fourteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 15.V10O1611097

# %%
V10O1611097= pd.read_csv('V10O1611097.csv')
V10O1611097.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611097 = V10O1611097.fillna(0)
V10O1611097['serial'] = '중계본동'
V10O1611097 = V10O1611097.applymap(lambda x: 0 if x==-999 else x)
V10O1611097['tm'] = V10O1611097.tm.apply(lambda x: str(x))
V10O1611097['tm'] = V10O1611097.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611097 = V10O1611097.set_index(['tm', 'serial'])
fifteen = V10O1611097.unstack()
fifteen = fifteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 16. V10O1611100

# %%
V10O1611100 = pd.read_csv('V10O1611100.csv')
V10O1611100.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611100 = V10O1611100.fillna(0)
V10O1611100['serial'] = '상계3.4동'
V10O1611100 = V10O1611100.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611100['tm'] = V10O1611100.tm.apply(lambda x: str(x))
V10O1611100['tm'] = V10O1611100.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611100 = V10O1611100.set_index(['tm', 'serial'])
sixteen = V10O1611100.unstack()
sixteen = sixteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 17. V10O1611102

# %%
V10O1611102= pd.read_csv('V10O1611102.csv')
V10O1611102.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611102 = V10O1611102.fillna(0)
V10O1611102['serial'] = '상계3.4동'
V10O1611102 = V10O1611102.applymap(lambda x: 0 if x==-999  or x==-9999 else x)
V10O1611102['tm'] = V10O1611102.tm.apply(lambda x: str(x))
V10O1611102['tm'] = V10O1611102.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611102 = V10O1611102.set_index(['tm', 'serial'])
seventeen = V10O1611102.unstack()
seventeen = seventeen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 18. V10O1611104

# %%
V10O1611104= pd.read_csv('V10O1611104.csv')
V10O1611104.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611104 = V10O1611104.fillna(0)
V10O1611104['serial'] = '상계3.4동'
V10O1611104 = V10O1611104.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611104['tm'] = V10O1611104.tm.apply(lambda x: str(x))
V10O1611104['tm'] = V10O1611104.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611104 = V10O1611104.set_index(['tm','serial'])
eighteen = V10O1611104.unstack()
eighteen = eighteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 19. V10O1611150

# %%
V10O1611150= pd.read_csv('V10O1611150.csv')
V10O1611150.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611150 = V10O1611150.fillna(0)
V10O1611150['serial'] = '상계3.4동'
V10O1611150 = V10O1611150.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611150['tm'] = V10O1611150.tm.apply(lambda x: str(x))
V10O1611150['tm'] = V10O1611150.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611150 = V10O1611150.set_index(['tm', 'serial'])
nineteen = V10O1611150.unstack()
nineteen = nineteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 20. V10O1611229

# %%
V10O1611229= pd.read_csv('V10O1611229.csv')
V10O1611229.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611229 = V10O1611229.fillna(0)
V10O1611229['serial'] = '월계1동'
V10O1611229 = V10O1611229.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611229['tm'] = V10O1611229.tm.apply(lambda x: str(x))
V10O1611229['tm'] = V10O1611229.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611229 = V10O1611229.set_index(['tm', 'serial'])
twenty = V10O1611229.unstack()
twenty = twenty.swaplevel(0,1,axis=1)

# %% [markdown]
# # 21. V10O1611652

# %%
V10O1611652= pd.read_csv('V10O1611652.csv')
V10O1611652.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611652 = V10O1611652.fillna(0)
V10O1611652['serial'] = '공릉2동'
V10O1611652 = V10O1611652.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611652['tm'] = V10O1611652.tm.apply(lambda x: str(x))
V10O1611652['tm'] = V10O1611652.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611652 = V10O1611652.set_index(['tm', 'serial'])
twentyone = V10O1611652.unstack()
twentyone = twentyone.swaplevel(0,1,axis=1)

# %% [markdown]
# # 22. V10O1612126

# %%
V10O1612126= pd.read_csv('V10O1612126.csv')
V10O1612126.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1612126 = V10O1612126.fillna(0)
V10O1612126['serial'] = '중계본동'
V10O1612126 = V10O1612126.applymap(lambda x: 0 if x==-999 else x)
V10O1612126['tm'] = V10O1612126.tm.apply(lambda x: str(x))
V10O1612126['tm'] = V10O1612126.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1612126 = V10O1612126.set_index(['tm', 'serial'])
twentytwo = V10O1612126.unstack()
twentytwo = twentytwo.swaplevel(0,1,axis=1)

# %%
노원구 = pd.concat([one,two,three,four,five,six,seven,eight,nine,ten,
          eleven,twelve, thirteen, fourteen, fifteen, sixteen, seventeen, eighteen,
          nineteen, twenty, twentyone, twentytwo], axis=1)

# %%
노원구.head()

# %%
노원구.columns

# %%
노원구 = 노원구.sort_index(axis=1)

# %%
노원구.head()

# %%
노원구.columns

# %%
노원구.info()

# %% [markdown]
# # 시간단위 Resampling

# %%
시간별_노원구 = 노원구.resample('1H').mean()
시간별_노원구.head(24)

# %%
type(시간별_노원구.iloc[0]['공릉2동']['pm10'])

# %% [markdown]
# # 행정동별 미세먼지 데이터

# %%
#import statistics


pm10_공릉2동 = [ 시간별_노원구.iloc[i]['공릉2동']['pm10'].mode('index') for i in range(len(시간별_노원구.index)) ] 
pm25_공릉2동 = [ 시간별_노원구.iloc[i]['공릉2동']['pm25'].mode('index') for i in range(len(시간별_노원구.index)) ]


pm10_상계34동 = [ 시간별_노원구.iloc[i]['상계3.4동']['pm10'].mode('index') for i in range(len(시간별_노원구.index)) ]
pm25_상계34동 = [ 시간별_노원구.iloc[i]['상계3.4동']['pm25'].mode('index') for i in range(len(시간별_노원구.index)) ]


pm10_월계1동 = [ 시간별_노원구.iloc[i]['월계1동']['pm10'].mode('index') for i in range(len(시간별_노원구.index)) ]
pm25_월계1동 = [ 시간별_노원구.iloc[i]['월계1동']['pm25'].mode('index') for i in range(len(시간별_노원구.index)) ]


pm10_중계본동 = [ 시간별_노원구.iloc[i]['중계본동']['pm10'].mode('index') for i in range(len(시간별_노원구.index)) ]
pm25_중계본동 = [ 시간별_노원구.iloc[i]['중계본동']['pm25'].mode('index') for i in range(len(시간별_노원구.index)) ]


pm10_하계1동 = [ 시간별_노원구.iloc[i]['하계1동']['pm10'].mode('index') for i in range(len(시간별_노원구.index)) ]
pm25_하계1동 = [ 시간별_노원구.iloc[i]['하계1동']['pm25'].mode('index') for i in range(len(시간별_노원구.index)) ]


"""
아래 코드는 다음과 같은 에러 발생-> Error code : AttributeError: 'numpy.float64' object has no attribute 'mode'

pm10_상계2동 = [ 시간별_노원구.iloc[i]['상계2동']['pm10'].mode() for i in range(len(시간별_노원구.index)) ]
pm25_상계2동 = [ 시간별_노원구.iloc[i]['상계2동']['pm25'].mode() for i in range(len(시간별_노원구.index)) ]

pm10_상계5동 = [ 시간별_노원구.iloc[i]['상계5동']['pm10'].mode() for i in range(len(시간별_노원구.index)) ]
pm25_상계5동 = [ 시간별_노원구.iloc[i]['상계5동']['pm25'].mode() for i in range(len(시간별_노원구.index)) ]

"""

# %% [markdown]
# # 하나의 데이터셋 데이터프레임 만들기

# %%
from pandas import DataFrame

관측치 = { "pm10_공릉2동" : pm10_공릉2동,
           "pm25_공릉2동" : pm25_공릉2동,
            "pm10_상계3.4동" : pm10_상계34동,
           "pm25_상계3.4동" : pm25_상계34동,
            "pm10_월계1동" : pm10_월계1동,
           "pm25_월계1동" : pm25_월계1동,
            "pm10_중계본동" : pm10_중계본동,
           "pm25_중계본동" : pm25_중계본동,
            "pm10_하계1동" : pm10_하계1동,
           "pm25_하계1동" : pm25_하계1동
    
      }

노원구 = pd.DataFrame(관측치, index=시간별_노원구.index)

# %%
노원구

# %% [markdown]
# # 시각화

# %%
# %matplotlib inline


노원구 = 노원구.astype(float)
노원구.plot()

# %%
노원구

# %%
시간별_노원구

# %% [markdown]
# # 행정동별 측정값 평균구하기
