# %% [markdown]
# # 2018.4월~2019.3월까지의 데이터
#
# ## tm: 데이터 측정날짜시간(YYYYMMDDhhmm)
# ## serial: 측정기 고유번호
# ## flag: 실외측정기 구분
# ## pm10 : 미세먼지 PM-10 데이터
# ## temp : 온도 데이터
# ## humi: 습도 데이터
# ## pm25: 미세먼지 PM-2.5 데이터

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# # 1. V01o1610468

# %%
# 필요없는 column 지우고, 결측값 0으로 채우기
V01o1610468 = pd.read_csv('환경기상데이터/종로구/V01o1610468.csv')
V01o1610468.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V01o1610468 = V01o1610468.fillna(0)
V01o1610468['serial'] = '도렴동'
V01o1610468 = V01o1610468.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V01o1610468['tm'] = V01o1610468.tm.apply(lambda x: str(x))
V01o1610468['tm'] = V01o1610468.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V01o1610468 = V01o1610468.set_index(['tm', 'serial'])
one = V01o1610468.unstack()
one = one.swaplevel(0,1,axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-fef819c75a64> in <module>()
# ----> 1 V01o1610468 = pd.read_csv('환경기상데이터/종로구/V01o1610468.csv')
#       2 V01o1610468.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
#       3 V01o1610468 = V01o1610468.fillna(0)
#       4 V01o1610468['serial'] = '도렴동'
#       5 V01o1610468 = V01o1610468.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
#
# ...

# %% [markdown]
# # 2. V10O1610252

# %%
V10O1610252 = pd.read_csv('환경기상데이터/종로구/V10O1610252.csv')
V10O1610252.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610252 = V10O1610252.fillna(0)
V10O1610252['serial'] = '교남동'
V10O1610252 = V10O1610252.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610252['tm'] = V10O1610252.tm.apply(lambda x: str(x))
V10O1610252['tm'] = V10O1610252.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610252 = V10O1610252.set_index(['tm', 'serial'])
two = V10O1610252.unstack()
two = two.swaplevel(0,1,axis=1)

# %% [markdown]
# # 3. V10O1610540

# %%
V10O1610540 = pd.read_csv('환경기상데이터/종로구/V10O1610540.csv')
V10O1610540.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610540 = V10O1610540.fillna(0)
V10O1610540['serial'] = '세종로 100'
V10O1610540 = V10O1610540.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610540['tm'] = V10O1610540.tm.apply(lambda x: str(x))
V10O1610540['tm'] = V10O1610540.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610540 = V10O1610540.set_index(['tm', 'serial'])
three = V10O1610540.unstack()
three = three.swaplevel(0,1,axis=1)

# %% [markdown]
# # 4. V10O1610542

# %%
V10O1610542= pd.read_csv('환경기상데이터/종로구/V10O1610542.csv')
V10O1610542.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610542 = V10O1610542.fillna(0)
V10O1610542['serial'] = '세종로 100'
V10O1610542 = V10O1610542.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610542['tm'] = V10O1610542.tm.apply(lambda x: str(x))
V10O1610542['tm'] = V10O1610542.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610542 = V10O1610542.set_index(['tm', 'serial'])
four = V10O1610542.unstack()
four = four.swaplevel(0,1,axis=1)

# %% [markdown]
# # 5. V10O1610543

# %%
V10O1610543= pd.read_csv('환경기상데이터/종로구/V10O1610543.csv')
V10O1610543.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610543 = V10O1610543.fillna(0)
V10O1610543['serial'] = '세종로 100'
V10O1610543 = V10O1610543.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610543['tm'] = V10O1610543.tm.apply(lambda x: str(x))
V10O1610543['tm'] = V10O1610543.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610543 = V10O1610543.set_index(['tm', 'serial'])
five = V10O1610543.unstack()
five = five.swaplevel(0,1,axis=1)

# %% [markdown]
# # 6. V10O1610544

# %%
V10O1610544= pd.read_csv('환경기상데이터/종로구/V10O1610544.csv')
V10O1610544.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610544 = V10O1610544.fillna(0)
V10O1610544['serial'] = '세종로 100'
V10O1610544 = V10O1610544.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610544['tm'] = V10O1610544.tm.apply(lambda x: str(x))
V10O1610544['tm'] = V10O1610544.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610544 = V10O1610544.set_index(['tm', 'serial'])
six = V10O1610544.unstack()
six = six.swaplevel(0,1,axis=1)

# %% [markdown]
# # 7. V10O1610545

# %%
V10O1610545= pd.read_csv('환경기상데이터/종로구/V10O1610545.csv')
V10O1610545.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610545 = V10O1610545.fillna(0)
V10O1610545['serial'] = '세종로 100'
V10O1610545 = V10O1610545.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610545['tm'] = V10O1610545.tm.apply(lambda x: str(x))
V10O1610545['tm'] = V10O1610545.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610545 = V10O1610545.set_index(['tm', 'serial'])
seven = V10O1610545.unstack()
seven = seven.swaplevel(0,1,axis=1)

# %% [markdown]
# # 8. V10O1610546

# %%
V10O1610546= pd.read_csv('환경기상데이터/종로구/V10O1610546.csv')
V10O1610546.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610546 = V10O1610546.fillna(0)
V10O1610546['serial'] = '세종로 100'
V10O1610546 = V10O1610546.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610546['tm'] = V10O1610546.tm.apply(lambda x: str(x))
V10O1610546['tm'] = V10O1610546.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610546 = V10O1610546.set_index(['tm', 'serial'])
eight = V10O1610546.unstack()
eight = eight.swaplevel(0,1,axis=1)

# %% [markdown]
# # 9. V10O1610567

# %%
V10O1610567= pd.read_csv('환경기상데이터/종로구/V10O1610567.csv')
V10O1610567.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1610567 = V10O1610567.fillna(0)
V10O1610567['serial'] = '세종로 100'
V10O1610567 = V10O1610567.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1610567['tm'] = V10O1610567.tm.apply(lambda x: str(x))
V10O1610567['tm'] = V10O1610567.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1610567 = V10O1610567.set_index(['tm', 'serial'])
nine = V10O1610567.unstack()
nine = nine.swaplevel(0,1,axis=1)

# %% [markdown]
# # 10.V10O1611145

# %%
V10O1611145= pd.read_csv('환경기상데이터/종로구/V10O1611145.csv')
V10O1611145.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611145 = V10O1611145.fillna(0)
V10O1611145['serial'] = '인사동'
V10O1611145 = V10O1611145.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611145['tm'] = V10O1611145.tm.apply(lambda x: str(x))
V10O1611145['tm'] = V10O1611145.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611145 = V10O1611145.set_index(['tm', 'serial'])
ten = V10O1611145.unstack()
ten = ten.swaplevel(0,1,axis=1)

# %% [markdown]
# # 11. V10O1611151

# %%
V10O1611151= pd.read_csv('환경기상데이터/종로구/V10O1611151.csv')
V10O1611151.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611151 = V10O1611151.fillna(0)
V10O1611151['serial'] = '창신동'
V10O1611151 = V10O1611151.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611151['tm'] = V10O1611151.tm.apply(lambda x: str(x))
V10O1611151['tm'] = V10O1611151.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611151 = V10O1611151.set_index(['tm', 'serial'])
eleven = V10O1611151.unstack()
eleven = eleven.swaplevel(0,1,axis=1)

# %% [markdown]
# # 12. V10O1611170

# %%
V10O1611170= pd.read_csv('환경기상데이터/종로구/V10O1611170.csv')
V10O1611170.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611170 = V10O1611170.fillna(0)
V10O1611170['serial'] = '신영동'
V10O1611170 = V10O1611170.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611170['tm'] = V10O1611170.tm.apply(lambda x: str(x))
V10O1611170['tm'] = V10O1611170.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611170 = V10O1611170.set_index(['tm', 'serial'])
twelve = V10O1611170.unstack()
twelve = twelve.swaplevel(0,1,axis=1)

# %% [markdown]
# # 13. V10O1611172

# %%
V10O1611172= pd.read_csv('환경기상데이터/종로구/V10O1611172.csv')
V10O1611172.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611172 = V10O1611172.fillna(0)
V10O1611172['serial'] = '내자동'
V10O1611172 = V10O1611172.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611172['tm'] = V10O1611172.tm.apply(lambda x: str(x))
V10O1611172['tm'] = V10O1611172.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611172 = V10O1611172.set_index(['tm', 'serial'])
thirteen = V10O1611172.unstack()
thirteen = thirteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 14. V10O1611173

# %%
V10O1611173= pd.read_csv('환경기상데이터/종로구/V10O1611173.csv')
V10O1611173.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611173 = V10O1611173.fillna(0)
V10O1611173['serial'] = '원남동'
V10O1611173 = V10O1611173.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611173['tm'] = V10O1611173.tm.apply(lambda x: str(x))
V10O1611173['tm'] = V10O1611173.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611173 = V10O1611173.set_index(['tm', 'serial'])
fourteen = V10O1611173.unstack()
fourteen = fourteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 15. V10O1611220

# %%
V10O1611220= pd.read_csv('환경기상데이터/종로구/V10O1611220.csv')
V10O1611220.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611220 = V10O1611220.fillna(0)
V10O1611220['serial'] = '창신동'
V10O1611220 = V10O1611220.applymap(lambda x: 0 if x==-999 else x)
V10O1611220['tm'] = V10O1611220.tm.apply(lambda x: str(x))
V10O1611220['tm'] = V10O1611220.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611220 = V10O1611220.set_index(['tm', 'serial'])
fifteen = V10O1611220.unstack()
fifteen = fifteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 16. V10O1611251

# %%
V10O1611251= pd.read_csv('환경기상데이터/종로구/V10O1611251.csv')
V10O1611251.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611251 = V10O1611251.fillna(0)
V10O1611251['serial'] = '창신동'
V10O1611251 = V10O1611251.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611251['tm'] = V10O1611251.tm.apply(lambda x: str(x))
V10O1611251['tm'] = V10O1611251.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611251 = V10O1611251.set_index(['tm', 'serial'])
sixteen = V10O1611251.unstack()
sixteen = sixteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 17. V10O1611255

# %%
V10O1611255= pd.read_csv('환경기상데이터/종로구/V10O1611255.csv')
V10O1611255.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611255 = V10O1611255.fillna(0)
V10O1611255['serial'] = '세종로 1-57'
V10O1611255 = V10O1611255.applymap(lambda x: 0 if x==-999  or x==-9999 else x)
V10O1611255['tm'] = V10O1611255.tm.apply(lambda x: str(x))
V10O1611255['tm'] = V10O1611255.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611255 = V10O1611255.set_index(['tm', 'serial'])
seventeen = V10O1611255.unstack()
seventeen = seventeen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 18. V10O1611258

# %%
V10O1611258= pd.read_csv('환경기상데이터/종로구/V10O1611258.csv')
V10O1611258.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611258 = V10O1611258.fillna(0)
V10O1611258['serial'] = '평창동'
V10O1611258 = V10O1611258.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611258['tm'] = V10O1611258.tm.apply(lambda x: str(x))
V10O1611258['tm'] = V10O1611258.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611258 = V10O1611258.set_index(['tm','serial'])
eighteen = V10O1611258.unstack()
eighteen = eighteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 19. V10O1611289

# %%
V10O1611289= pd.read_csv('환경기상데이터/종로구/V10O1611289.csv')
V10O1611289.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611289 = V10O1611289.fillna(0)
V10O1611289['serial'] = '영천동'
V10O1611289 = V10O1611289.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611289['tm'] = V10O1611289.tm.apply(lambda x: str(x))
V10O1611289['tm'] = V10O1611289.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611289 = V10O1611289.set_index(['tm', 'serial'])
nineteen = V10O1611289.unstack()
nineteen = nineteen.swaplevel(0,1,axis=1)

# %% [markdown]
# # 20. V10O1611623

# %%
V10O1611623= pd.read_csv('환경기상데이터/종로구/V10O1611623.csv')
V10O1611623.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611623 = V10O1611623.fillna(0)
V10O1611623['serial'] = '명륜동4가'
V10O1611623 = V10O1611623.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611623['tm'] = V10O1611623.tm.apply(lambda x: str(x))
V10O1611623['tm'] = V10O1611623.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611623 = V10O1611623.set_index(['tm', 'serial'])
twenty = V10O1611623.unstack()
twenty = twenty.swaplevel(0,1,axis=1)

# %% [markdown]
# # 21. V10O1611634

# %%
V10O1611634= pd.read_csv('환경기상데이터/종로구/V10O1611634.csv')
V10O1611634.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611634 = V10O1611634.fillna(0)
V10O1611634['serial'] = '재동'
V10O1611634 = V10O1611634.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611634['tm'] = V10O1611634.tm.apply(lambda x: str(x))
V10O1611634['tm'] = V10O1611634.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611634 = V10O1611634.set_index(['tm', 'serial'])
twentyone = V10O1611634.unstack()
twentyone = twentyone.swaplevel(0,1,axis=1)

# %% [markdown]
# # 22. V10O1611639

# %%
V10O1611639= pd.read_csv('환경기상데이터/종로구/V10O1611639.csv')
V10O1611639.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611639 = V10O1611639.fillna(0)
V10O1611639['serial'] = '종로5가 20-2'
V10O1611639 = V10O1611639.applymap(lambda x: 0 if x==-999 else x)
V10O1611639['tm'] = V10O1611639.tm.apply(lambda x: str(x))
V10O1611639['tm'] = V10O1611639.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611639 = V10O1611639.set_index(['tm', 'serial'])
twentytwo = V10O1611639.unstack()
twentytwo = twentytwo.swaplevel(0,1,axis=1)

# %% [markdown]
# # 23. V10O1611645

# %%
V10O1611645= pd.read_csv('환경기상데이터/종로구/V10O1611645.csv')
V10O1611645.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611645 = V10O1611645.fillna(0)
V10O1611645['serial'] = '명륜1가 72-3'
V10O1611645 = V10O1611645.applymap(lambda x: 0 if x==-999  or x==-9999 else x)
V10O1611645['tm'] = V10O1611645.tm.apply(lambda x: str(x))
V10O1611645['tm'] = V10O1611645.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611645 = V10O1611645.set_index(['tm', 'serial'])
twentythree = V10O1611645.unstack()
twentythree = twentythree.swaplevel(0,1,axis=1)

# %% [markdown]
# # 24. V10O1611658

# %%
V10O1611658= pd.read_csv('환경기상데이터/종로구/V10O1611658.csv')
V10O1611658.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611658= V10O1611658.fillna(0)
V10O1611658['serial'] = '연건동'
V10O1611658 = V10O1611658.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611658['tm'] = V10O1611658.tm.apply(lambda x: str(x))
V10O1611658['tm'] = V10O1611658.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611658 = V10O1611658.set_index(['tm', 'serial'])
twentyfour = V10O1611658.unstack()
twentyfour = twentyfour.swaplevel(0,1,axis=1)

# %% [markdown]
# # 25. V10O1611684

# %%
V10O1611684= pd.read_csv('환경기상데이터/종로구/V10O1611684.csv')
V10O1611684.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611684= V10O1611684.fillna(0)
V10O1611684['serial'] = '공평동'
V10O1611684 = V10O1611684.applymap(lambda x: 0 if x==-999  or x==-9999 else x)
V10O1611684['tm'] = V10O1611684.tm.apply(lambda x: str(x))
V10O1611684['tm'] = V10O1611684.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611684 = V10O1611684.set_index(['tm', 'serial'])
twentyfive = V10O1611684.unstack()
twentyfive = twentyfive.swaplevel(0,1,axis=1)

# %% [markdown]
# # 26. V10O1611698

# %%
V10O1611698= pd.read_csv('환경기상데이터/종로구/V10O1611698.csv')
V10O1611698.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611698= V10O1611698.fillna(0)
V10O1611698['serial'] = '원서동'
V10O1611698 = V10O1611698.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611698['tm'] = V10O1611698.tm.apply(lambda x: str(x))
V10O1611698['tm'] = V10O1611698.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611698 = V10O1611698.set_index(['tm','serial'])
twentysix = V10O1611698.unstack()
twentysix = twentysix.swaplevel(0,1,axis=1)

# %% [markdown]
# # 27. V10O1611722

# %%
V10O1611722= pd.read_csv('환경기상데이터/종로구/V10O1611722.csv')
V10O1611722.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611722= V10O1611722.fillna(0)
V10O1611722['serial'] = '가회동'
V10O1611722 = V10O1611722.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611722['tm'] = V10O1611722.tm.apply(lambda x: str(x))
V10O1611722['tm'] = V10O1611722.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611722 = V10O1611722.set_index(['tm', 'serial'])
twentyseven = V10O1611722.unstack()
twentyseven = twentyseven.swaplevel(0,1,axis=1)

# %% [markdown]
# # 28. V10O1611750

# %%
V10O1611750= pd.read_csv('환경기상데이터/종로구/V10O1611750.csv')
V10O1611750.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611750= V10O1611750.fillna(0)
V10O1611750['serial'] = '묘동'
V10O1611750 = V10O1611750.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611750['tm'] = V10O1611750.tm.apply(lambda x: str(x))
V10O1611750['tm'] = V10O1611750.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611750 = V10O1611750.set_index(['tm', 'serial'])
twentyeight = V10O1611750.unstack()
twentyeight = twentyeight.swaplevel(0,1,axis=1)

# %% [markdown]
# # 29. V10O1611887

# %%
V10O1611887= pd.read_csv('환경기상데이터/종로구/V10O1611887.csv')
V10O1611887.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1611887= V10O1611887.fillna(0)
V10O1611887['serial'] = '태평로1가 68-2'
V10O1611887 = V10O1611887.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1611887['tm'] = V10O1611887.tm.apply(lambda x: str(x))
V10O1611887['tm'] = V10O1611887.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1611887 = V10O1611887.set_index(['tm', 'serial'])
twentynine = V10O1611887.unstack()
twentynine = twentynine.swaplevel(0,1,axis=1)

# %% [markdown]
# # 30.V10O1612106

# %%
V10O1612106= pd.read_csv('환경기상데이터/종로구/V10O1612106.csv')
V10O1612106.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1612106= V10O1612106.fillna(0)
V10O1612106['serial'] = '숭인동'
V10O1612106 = V10O1612106.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1612106['tm'] = V10O1612106.tm.apply(lambda x: str(x))
V10O1612106['tm'] = V10O1612106.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1612106 = V10O1612106.set_index(['tm', 'serial'])
thirty = V10O1612106.unstack()
thirty = thirty.swaplevel(0,1,axis=1)

# %% [markdown]
# # 31. V10O1612113

# %%
V10O1612113= pd.read_csv('환경기상데이터/종로구/V10O1612113.csv')
V10O1612113.drop(['co2', 'vocs', 'noise', 'Unnamed: 10'], axis=1, inplace=True)
V10O1612113['serial'] = '세종로 100'
V10O1612113= V10O1612113.fillna(0)
V10O1612113 = V10O1612113.applymap(lambda x: 0 if x==-999 or x==-9999 else x)
V10O1612113['tm'] = V10O1612113.tm.apply(lambda x: str(x))
V10O1612113['tm'] = V10O1612113.tm.apply(lambda x: datetime.strptime(x, '%Y%m%d%H%M'))
V10O1612113 = V10O1612113.set_index(['tm', 'serial'])
thirtyone = V10O1612113.unstack()
thirtyone = thirtyone.swaplevel(0,1,axis=1)

# %%
thirtyone

# %%
종로구전처리 = pd.concat([one,two,three,four,five,six,seven,eight,nine,ten,
          eleven,twelve, thirteen, fourteen, fifteen, sixteen, seventeen, eighteen,
          nineteen, twenty, twentyone, twentytwo, twentythree, twentyfour, twentyfive,
          twentysix, twentyseven, twentyeight, twentynine, thirty, thirtyone], axis=1)

# %%
종로구전처리
